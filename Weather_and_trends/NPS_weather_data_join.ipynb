# %%
import numpy as np
import pandas as pd
import requests
import json
from datetime import datetime
import time

# %%
s_id_2021={}
s_id_2021['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2021['Arches National Park'] = ['GHCND:USW00093075']
s_id_2021['Badlands National Park'] = ['GHCND:USR0000SPNN']
s_id_2021['Big Bend National Park'] = ['GHCND:USC00416792']
s_id_2021['Biscayne National Park'] = ['GHCND:USC00087760']
s_id_2021['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2021['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2021['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2021['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2021['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2021['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2021['Congaree National Park'] = ['GHCND:USC00386775']
s_id_2021['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2021['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2021['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2021['Denali National Park'] = ['GHCND:USW00096408']
s_id_2021['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2021['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2021['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2021['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2021['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2021['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2021['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2021['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2021['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2021['Great Sand Dunes National Park'] = ['GHCND:USC00053541']
s_id_2021['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2021['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2021['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2021['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2021['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2021['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2021['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2021['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2021['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2021['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2021['Kings Canyon National Park'] = ['GHCND:USR0000CPKR']
s_id_2021['Kobuk Valley National Park'] = ['GHCND:USR0000ASLR']
s_id_2021['Lake Clark National Park'] = ['GHCND:USR0000ASWA']
s_id_2021['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2021['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2021['Mesa Verde National Park'] = ['GHCND:USC00290692']
s_id_2021['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2021['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2021['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2021['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2021['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2021['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2021['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2021['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2021['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2021['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2021['Sequoia National Park'] = ['GHCND:USR0000CCMO']
s_id_2021['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2021['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2021['Virgin Islands National Park'] = ['GHCND:VQW00011640']
s_id_2021['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2021['White Sands National Park'] = ['GHCND:USC00299686']
s_id_2021['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2021['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2021['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2021['Yosemite National Park'] = ['GHCND:USR0000CMET']
s_id_2021['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2020={}
s_id_2020['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2020['Arches National Park'] = ['GHCND:USW00093075']
s_id_2020['Badlands National Park'] = ['GHCND:USR0000SPNN']
s_id_2020['Big Bend National Park'] = ['GHCND:USC00416792']
s_id_2020['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2020['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2020['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2020['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2020['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2020['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2020['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2020['Congaree National Park'] = ['GHCND:USC00386775']
s_id_2020['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2020['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2020['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2020['Denali National Park'] = ['GHCND:USW00096408']
s_id_2020['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2020['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2020['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2020['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2020['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2020['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2020['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2020['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2020['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2020['Great Sand Dunes National Park'] = ['GHCND:USC00053541']
s_id_2020['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2020['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2020['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2020['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2020['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2020['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2020['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2020['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2020['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2020['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2020['Kings Canyon National Park'] = ['GHCND:USR0000CPKR']
s_id_2020['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2020['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2020['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2020['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2020['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2020['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2020['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2020['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2020['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2020['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2020['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2020['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2020['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2020['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2020['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2020['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2020['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2020['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2020['Virgin Islands National Park'] = ['GHCND:VQC00671740']
s_id_2020['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2020['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2020['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2020['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2020['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2020['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2020['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2019={}
s_id_2019['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2019['Arches National Park'] = ['GHCND:USW00093075']
s_id_2019['Badlands National Park'] = ['GHCND:USR0000SPNN']
s_id_2019['Big Bend National Park'] = ['GHCND:USC00416792']
s_id_2019['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2019['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2019['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2019['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2019['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2019['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2019['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2019['Congaree National Park'] = ['GHCND:USC00385493']
s_id_2019['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2019['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2019['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2019['Denali National Park'] = ['GHCND:USW00096408']
s_id_2019['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2019['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2019['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2019['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2019['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2019['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2019['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2019['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2019['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2019['Great Sand Dunes National Park'] = ['GHCND:USC00053541']
s_id_2019['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2019['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2019['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2019['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2019['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2019['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2019['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2019['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2019['Katmai National Park'] = ['GHCND:USR0000APAL']
s_id_2019['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2019['Kings Canyon National Park'] = ['GHCND:USR0000CPIH']
s_id_2019['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2019['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2019['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2019['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2019['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2019['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2019['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2019['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2019['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2019['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2019['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2019['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2019['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2019['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2019['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2019['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2019['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2019['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2019['Virgin Islands National Park'] = ['GHCND:VQC00671740']
s_id_2019['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2019['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2019['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2019['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2019['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2019['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2019['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2018={}
s_id_2018['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2018['Arches National Park'] = ['GHCND:USW00093075']
s_id_2018['Badlands National Park'] = ['GHCND:USR0000SPIN']
s_id_2018['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2018['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2018['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2018['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2018['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2018['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2018['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2018['Channel Islands National Park'] = ['GHCND:USR0000CSAU']
s_id_2018['Congaree National Park'] = ['GHCND:USC00386299']
s_id_2018['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2018['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2018['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2018['Denali National Park'] = ['GHCND:USR0000AEIE']
s_id_2018['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2018['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2018['Gates of the Arctic National Park'] = ['GHCND:USR0000AKLP']
s_id_2018['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2018['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2018['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2018['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2018['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2018['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2018['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2018['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2018['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2018['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2018['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2018['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2018['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2018['Isle Royale National Park'] = ['GHCND:USR0000MOJI']
s_id_2018['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2018['Katmai National Park'] = ['GHCND:USR0000APAL']
s_id_2018['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2018['Kings Canyon National Park'] = ['GHCND:USR0000CPIH']
s_id_2018['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2018['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2018['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2018['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2018['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2018['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2018['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2018['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2018['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2018['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2018['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2018['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2018['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2018['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2018['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2018['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2018['Shenandoah National Park'] = ['GHCND:USC00447985']
s_id_2018['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2018['Virgin Islands National Park'] = ['GHCND:VQW00011624']
s_id_2018['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2018['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2018['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2018['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2018['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2018['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2018['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2017={}
s_id_2017['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2017['Arches National Park'] = ['GHCND:USW00093075']
s_id_2017['Badlands National Park'] = ['GHCND:USR0000SPIN']
s_id_2017['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2017['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2017['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2017['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2017['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2017['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2017['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2017['Channel Islands National Park'] = ['GHCND:USR0000CSCI']
s_id_2017['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2017['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2017['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2017['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2017['Denali National Park'] = ['GHCND:USR0000AEIE']
s_id_2017['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2017['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2017['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2017['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2017['Glacier Bay National Park'] = ['GHCND:USR0000AHON']
s_id_2017['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2017['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2017['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2017['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2017['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2017['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2017['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2017['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2017['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2017['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2017['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2017['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2017['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2017['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2017['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2017['Kings Canyon National Park'] = ['GHCND:USR0000CPIH']
s_id_2017['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2017['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2017['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2017['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2017['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2017['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2017['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2017['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2017['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2017['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2017['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2017['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2017['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2017['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2017['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2017['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2017['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2017['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2017['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2017['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2017['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2017['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2017['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2017['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2017['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2017['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2016={}
s_id_2016['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2016['Arches National Park'] = ['GHCND:USW00093075']
s_id_2016['Badlands National Park'] = ['GHCND:USR0000SPIN']
s_id_2016['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2016['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2016['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2016['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2016['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2016['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2016['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2016['Channel Islands National Park'] = ['GHCND:USR0000CSCI']
s_id_2016['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2016['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2016['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2016['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2016['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2016['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2016['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2016['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2016['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2016['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2016['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2016['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2016['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2016['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2016['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2016['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2016['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2016['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2016['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2016['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2016['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2016['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2016['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2016['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2016['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2016['Kings Canyon National Park'] = ['GHCND:USR0000CPIH']
s_id_2016['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2016['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2016['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2016['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2016['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2016['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2016['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2016['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2016['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2016['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2016['Petrified Forest National Park'] = ['GHCND:USC00027435']
s_id_2016['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2016['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2016['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2016['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2016['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2016['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2016['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2016['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2016['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2016['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2016['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2016['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2016['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2016['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2016['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2015={}
s_id_2015['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2015['Arches National Park'] = ['GHCND:USW00093075']
s_id_2015['Badlands National Park'] = ['GHCND:USR0000SPIN']
s_id_2015['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2015['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2015['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2015['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2015['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2015['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2015['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2015['Channel Islands National Park'] = ['GHCND:USR0000CSRI']
s_id_2015['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2015['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2015['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2015['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2015['Denali National Park'] = ['GHCND:USR0000AWON']
s_id_2015['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2015['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2015['Gates of the Arctic National Park'] = ['GHCND:USR0000APAM']
s_id_2015['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2015['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2015['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2015['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2015['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2015['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2015['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2015['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2015['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2015['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2015['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HKMO']
s_id_2015['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2015['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2015['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2015['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2015['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2015['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2015['Kings Canyon National Park'] = ['GHCND:USR0000CPIH']
s_id_2015['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2015['Lake Clark National Park'] = ['GHCND:USR0000ACHG']
s_id_2015['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2015['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2015['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2015['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2015['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2015['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2015['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2015['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2015['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2015['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2015['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2015['Rocky Mountain National Park'] = ['GHCND:USR0000CEST']
s_id_2015['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2015['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2015['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2015['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2015['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2015['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2015['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2015['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2015['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2015['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2015['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2015['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2014={}
s_id_2014['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2014['Arches National Park'] = ['GHCND:USW00093075']
s_id_2014['Badlands National Park'] = ['GHCND:USC00394184']
s_id_2014['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2014['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2014['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2014['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2014['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2014['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2014['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2014['Channel Islands National Park'] = ['GHCND:USR0000CSCI']
s_id_2014['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2014['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2014['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2014['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2014['Denali National Park'] = ['GHCND:USR0000AWON']
s_id_2014['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2014['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2014['Gates of the Arctic National Park'] = ['GHCND:USR0000APAM']
s_id_2014['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2014['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2014['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2014['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2014['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2014['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2014['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2014['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2014['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2014['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2014['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HPAL']
s_id_2014['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2014['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2014['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2014['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2014['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2014['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2014['Kings Canyon National Park'] = ['GHCND:USR0000CCDG']
s_id_2014['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2014['Lake Clark National Park'] = ['GHCND:USR0000ACHG']
s_id_2014['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2014['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2014['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2014['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2014['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2014['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2014['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2014['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2014['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2014['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2014['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2014['Rocky Mountain National Park'] = ['GHCND:USC00052761']
s_id_2014['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2014['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2014['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2014['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2014['Virgin Islands National Park'] = ['GHCND:VQW00011624']
s_id_2014['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2014['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2014['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2014['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2014['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2014['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2014['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2013={}
s_id_2013['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2013['Arches National Park'] = ['GHCND:USC00425733']
s_id_2013['Badlands National Park'] = ['GHCND:USC00394184']
s_id_2013['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2013['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2013['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2013['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2013['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2013['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2013['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2013['Channel Islands National Park'] = ['GHCND:USR0000CSCI']
s_id_2013['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2013['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2013['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2013['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2013['Denali National Park'] = ['GHCND:USR0000AWON']
s_id_2013['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2013['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2013['Gates of the Arctic National Park'] = ['GHCND:USR0000ANOR']
s_id_2013['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2013['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2013['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2013['Grand Canyon National Park'] = ['GHCND:USR0000ADRY']
s_id_2013['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2013['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2013['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2013['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2013['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2013['Haleakala National Park'] = ['GHCND:USR0000HKAU']
s_id_2013['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HPAL']
s_id_2013['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2013['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2013['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2013['Joshua Tree National Park'] = ['GHCND:USR0000CFAW']
s_id_2013['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2013['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2013['Kings Canyon National Park'] = ['GHCND:USR0000COCR']
s_id_2013['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2013['Lake Clark National Park'] = ['GHCND:USW00026562']
s_id_2013['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2013['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2013['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2013['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2013['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2013['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2013['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2013['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2013['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2013['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2013['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2013['Rocky Mountain National Park'] = ['GHCND:USC00052761']
s_id_2013['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2013['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2013['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2013['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2013['Virgin Islands National Park'] = ['GHCND:VQW00011640']
s_id_2013['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2013['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2013['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2013['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2013['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2013['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2013['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2012={}
s_id_2012['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2012['Arches National Park'] = ['GHCND:USC00425733']
s_id_2012['Badlands National Park'] = ['GHCND:USC00394184']
s_id_2012['Big Bend National Park'] = ['GHCND:USR0000TCHI']
s_id_2012['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2012['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2012['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2012['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2012['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2012['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2012['Channel Islands National Park'] = ['GHCND:USR0000CSRI']
s_id_2012['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2012['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2012['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2012['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2012['Denali National Park'] = ['GHCND:USR0000AWON']
s_id_2012['Dry Tortugas National Park'] = ['GHCND:USW00012836']
s_id_2012['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2012['Gates of the Arctic National Park'] = ['GHCND:USR0000ANOR']
s_id_2012['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2012['Glacier Bay National Park'] = ['GHCND:USW00025322']
s_id_2012['Glacier National Park'] = ['GHCND:USS0013A27S']
s_id_2012['Grand Canyon National Park'] = ['GHCND:USR0000ACAN']
s_id_2012['Grand Teton National Park'] = ['GHCND:USS0010F02S']
s_id_2012['Great Basin National Park'] = ['GHCND:USC00263340']
s_id_2012['Great Sand Dunes National Park'] = ['GHCND:USS0005M16S']
s_id_2012['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2012['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2012['Haleakala National Park'] = ['GHCND:USC00517000']
s_id_2012['Hawaii Volcanoes National Park'] = ['GHCND:USR0000HPAL']
s_id_2012['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2012['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2012['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2012['Joshua Tree National Park'] = ['GHCND:USR0000CLHO']
s_id_2012['Katmai National Park'] = ['GHCND:USW00025503']
s_id_2012['Kenai Fjords National Park'] = ['GHCND:USR0000ABRO']
s_id_2012['Kings Canyon National Park'] = ['GHCND:USR0000COCR']
s_id_2012['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2012['Lake Clark National Park'] = ['GHCND:USW00026562']
s_id_2012['Lassen Volcanic National Park'] = ['GHCND:USR0000CMAN']
s_id_2012['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2012['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2012['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2012['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2012['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2012['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2012['Olympic National Park'] = ['GHCND:USR0000WCOU']
s_id_2012['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2012['Pinnacles National Park'] = ['GHCND:USR0000CLST']
s_id_2012['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2012['Rocky Mountain National Park'] = ['GHCND:USC00052761']
s_id_2012['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2012['Sequoia National Park'] = ['GHCND:USR0000CWOL']
s_id_2012['Shenandoah National Park'] = ['GHCND:USC00448941']
s_id_2012['Theodore Roosevelt National Park'] = ['GHCND:USR0000NSCK']
s_id_2012['Virgin Islands National Park'] = ['GHCND:VQW00011640']
s_id_2012['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2012['White Sands National Park'] = ['GHCND:USW00003074']
s_id_2012['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2012['Wrangell-St. Elias National Park'] = ['GHCND:USR0000AGAT']
s_id_2012['Yellowstone National Park'] = ['GHCND:USC00485345']
s_id_2012['Yosemite National Park'] = ['GHCND:USR0000CMSA']
s_id_2012['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2021_prcp={}
s_id_2021_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2021_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2021_prcp['Badlands National Park'] = ['GHCND:US1SDFR0034']
s_id_2021_prcp['Big Bend National Park'] = ['GHCND:USC00416792']
s_id_2021_prcp['Biscayne National Park'] = ['GHCND:USC00087760']
s_id_2021_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2021_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2021_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2021_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2021_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2021_prcp['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2021_prcp['Congaree National Park'] = ['GHCND:USC00386775']
s_id_2021_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2021_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2021_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2021_prcp['Denali National Park'] = ['GHCND:USW00096408']
s_id_2021_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2021_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2021_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2021_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2021_prcp['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2021_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2021_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2021_prcp['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2021_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2021_prcp['Great Sand Dunes National Park'] = ['GHCND:USC00053541']
s_id_2021_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2021_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2021_prcp['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2021_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USC00512595']
s_id_2021_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2021_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2021_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2021_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2021_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2021_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2021_prcp['Kings Canyon National Park'] = ['GHCND:US1CASS0007']
s_id_2021_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2021_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2021_prcp['Lassen Volcanic National Park'] = ['GHCND:US1CASH0006']
s_id_2021_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2021_prcp['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2021_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2021_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2021_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2021_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2021_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2021_prcp['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2021_prcp['Pinnacles National Park'] = ['GHCND:US1CAAL0012']
s_id_2021_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2021_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2021_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2021_prcp['Sequoia National Park'] = ['GHCND:US1CAKN0017']
s_id_2021_prcp['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2021_prcp['Theodore Roosevelt National Park'] = ['GHCND:USC00322188']
s_id_2021_prcp['Virgin Islands National Park'] = ['GHCND:VQ1VISJ0005']
s_id_2021_prcp['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2021_prcp['White Sands National Park'] = ['GHCND:USC00299686']
s_id_2021_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2021_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2021_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2021_prcp['Yosemite National Park'] = ['GHCND:US1CASS0007']
s_id_2021_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2020_prcp={}
s_id_2020_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2020_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2020_prcp['Badlands National Park'] = ['GHCND:US1SDFR0034']
s_id_2020_prcp['Big Bend National Park'] = ['GHCND:USC00416792']
s_id_2020_prcp['Biscayne National Park'] = ['GHCND:USC00084412']
s_id_2020_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2020_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2020_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2020_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2020_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2020_prcp['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2020_prcp['Congaree National Park'] = ['GHCND:USC00386775']
s_id_2020_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2020_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2020_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2020_prcp['Denali National Park'] = ['GHCND:USW00096408']
s_id_2020_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2020_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2020_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2020_prcp['Gateway Arch National Park'] = ['GHCND:USC00237452']
s_id_2020_prcp['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2020_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2020_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2020_prcp['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2020_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2020_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2020_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2020_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2020_prcp['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2020_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USC00512595']
s_id_2020_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2020_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2020_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2020_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2020_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2020_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2020_prcp['Kings Canyon National Park'] = ['GHCND:US1CASS0007']
s_id_2020_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2020_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2020_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2020_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2020_prcp['Mesa Verde National Park'] = ['GHCND:USW00003061']
s_id_2020_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2020_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2020_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2020_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2020_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2020_prcp['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2020_prcp['Pinnacles National Park'] = ['GHCND:US1CAAL0012']
s_id_2020_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2020_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2020_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2020_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2020_prcp['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2020_prcp['Theodore Roosevelt National Park'] = ['GHCND:USC00322188']
s_id_2020_prcp['Virgin Islands National Park'] = ['GHCND:VQC00672551']
s_id_2020_prcp['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2020_prcp['White Sands National Park'] = ['GHCND:US1NMOT0008']
s_id_2020_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2020_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2020_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2020_prcp['Yosemite National Park'] = ['GHCND:US1CASS0007']
s_id_2020_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2019_prcp={}
s_id_2019_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2019_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2019_prcp['Badlands National Park'] = ['GHCND:US1SDFR0034']
s_id_2019_prcp['Big Bend National Park'] = ['GHCND:USW00022016']
s_id_2019_prcp['Biscayne National Park'] = ['GHCND:USC00084412']
s_id_2019_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2019_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2019_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2019_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2019_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2019_prcp['Channel Islands National Park'] = ['GHCND:USW00093110']
s_id_2019_prcp['Congaree National Park'] = ['GHCND:USC00386775']
s_id_2019_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2019_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2019_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2019_prcp['Denali National Park'] = ['GHCND:USW00096408']
s_id_2019_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2019_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2019_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2019_prcp['Gateway Arch National Park'] = ['GHCND:USC00237452']
s_id_2019_prcp['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2019_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2019_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2019_prcp['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2019_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2019_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2019_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2019_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2019_prcp['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2019_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2019_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2019_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2019_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2019_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2019_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2019_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2019_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2019_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2019_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2019_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2019_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2019_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2019_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2019_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2019_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2019_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2019_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2019_prcp['Petrified Forest National Park'] = ['GHCND:US1AZNV0035']
s_id_2019_prcp['Pinnacles National Park'] = ['GHCND:US1CAAL0012']
s_id_2019_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2019_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2019_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2019_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2019_prcp['Shenandoah National Park'] = ['GHCND:USC00445096']
s_id_2019_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2019_prcp['Virgin Islands National Park'] = ['GHCND:VQC00672551']
s_id_2019_prcp['Voyageurs National Park'] = ['GHCND:USC00214191']
s_id_2019_prcp['White Sands National Park'] = ['GHCND:US1NMOT0008']
s_id_2019_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2019_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2019_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2019_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2019_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2018_prcp={}
s_id_2018_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2018_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2018_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2018_prcp['Big Bend National Park'] = ['GHCND:USW00022016']
s_id_2018_prcp['Biscayne National Park'] = ['GHCND:USC00084412']
s_id_2018_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2018_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2018_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2018_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2018_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2018_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2018_prcp['Congaree National Park'] = ['GHCND:US1SCRC0030']
s_id_2018_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2018_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2018_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2018_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2018_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2018_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2018_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2018_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2018_prcp['Glacier Bay National Park'] = ['GHCND:USC00504107']
s_id_2018_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2018_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2018_prcp['Grand Teton National Park'] = ['GHCND:USC00486440']
s_id_2018_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2018_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2018_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2018_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2018_prcp['Haleakala National Park'] = ['GHCND:USC00515004']
s_id_2018_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2018_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2018_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2018_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2018_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2018_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2018_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2018_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2018_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2018_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2018_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2018_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2018_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2018_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2018_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2018_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2018_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2018_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2018_prcp['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2018_prcp['Pinnacles National Park'] = ['GHCND:US1CAAL0012']
s_id_2018_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2018_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2018_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2018_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2018_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2018_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2018_prcp['Virgin Islands National Park'] = ['GHCND:VQC00672551']
s_id_2018_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2018_prcp['White Sands National Park'] = ['GHCND:US1NMOT0008']
s_id_2018_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2018_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2018_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2018_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2018_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2017_prcp={}
s_id_2017_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2017_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2017_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2017_prcp['Big Bend National Park'] = ['GHCND:USW00022016']
s_id_2017_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2017_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2017_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2017_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2017_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2017_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2017_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2017_prcp['Congaree National Park'] = ['GHCND:US1SCRC0030']
s_id_2017_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2017_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2017_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2017_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2017_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2017_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2017_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2017_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2017_prcp['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2017_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2017_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2017_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2017_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2017_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2017_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00406328']
s_id_2017_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2017_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2017_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2017_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2017_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2017_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2017_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2017_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2017_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2017_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2017_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2017_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2017_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2017_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2017_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2017_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2017_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2017_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2017_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2017_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2017_prcp['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2017_prcp['Pinnacles National Park'] = ['GHCND:US1CAAL0012']
s_id_2017_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2017_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2017_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2017_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2017_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2017_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2017_prcp['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2017_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2017_prcp['White Sands National Park'] = ['GHCND:US1NMOT0008']
s_id_2017_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2017_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2017_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2017_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2017_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2016_prcp={}
s_id_2016_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2016_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2016_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2016_prcp['Big Bend National Park'] = ['GHCND:US1TXBRS023']
s_id_2016_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2016_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2016_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2016_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2016_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2016_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2016_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2016_prcp['Congaree National Park'] = ['GHCND:US1SCRC0030']
s_id_2016_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2016_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2016_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2016_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2016_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2016_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2016_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2016_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2016_prcp['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2016_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2016_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2016_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2016_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2016_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2016_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2016_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2016_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2016_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2016_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2016_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2016_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2016_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2016_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2016_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2016_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2016_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2016_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2016_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2016_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2016_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2016_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2016_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2016_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2016_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2016_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2016_prcp['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2016_prcp['Pinnacles National Park'] = ['GHCND:USC00046926']
s_id_2016_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2016_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2016_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2016_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2016_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2016_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2016_prcp['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2016_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2016_prcp['White Sands National Park'] = ['GHCND:USC00299686']
s_id_2016_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2016_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2016_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2016_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2016_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2015_prcp={}
s_id_2015_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2015_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2015_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2015_prcp['Big Bend National Park'] = ['GHCND:US1TXBRS023']
s_id_2015_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2015_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2015_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2015_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2015_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2015_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2015_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2015_prcp['Congaree National Park'] = ['GHCND:US1SCRC0030']
s_id_2015_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2015_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2015_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2015_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2015_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2015_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2015_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2015_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2015_prcp['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2015_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2015_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2015_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2015_prcp['Great Basin National Park'] = ['GHCND:USS0014K07S']
s_id_2015_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2015_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2015_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2015_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2015_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2015_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2015_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2015_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2015_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2015_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2015_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2015_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2015_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2015_prcp['Lake Clark National Park'] = ['GHCND:USS0053L01S']
s_id_2015_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2015_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2015_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2015_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2015_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2015_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2015_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2015_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2015_prcp['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2015_prcp['Pinnacles National Park'] = ['GHCND:USC00046926']
s_id_2015_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2015_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2015_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2015_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2015_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2015_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2015_prcp['Virgin Islands National Park'] = ['GHCND:RQC00666343']
s_id_2015_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2015_prcp['White Sands National Park'] = ['GHCND:US1NMOT0065']
s_id_2015_prcp['Wind Cave National Park'] = ['GHCND:USW00094032']
s_id_2015_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2015_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2015_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2015_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2014_prcp={}
s_id_2014_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2014_prcp['Arches National Park'] = ['GHCND:USW00093075']
s_id_2014_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2014_prcp['Big Bend National Park'] = ['GHCND:USC00418924']
s_id_2014_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2014_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2014_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2014_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2014_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2014_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2014_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2014_prcp['Congaree National Park'] = ['GHCND:US1SCRC0030']
s_id_2014_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2014_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2014_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2014_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2014_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2014_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2014_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2014_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2014_prcp['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2014_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2014_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2014_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2014_prcp['Great Basin National Park'] = ['GHCND:USC00263340']
s_id_2014_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2014_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2014_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2014_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2014_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2014_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2014_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2014_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2014_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2014_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2014_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2014_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2014_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2014_prcp['Lake Clark National Park'] = ['GHCND:USW00026562']
s_id_2014_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2014_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2014_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2014_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2014_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2014_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2014_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2014_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2014_prcp['Petrified Forest National Park'] = ['GHCND:USC00026468']
s_id_2014_prcp['Pinnacles National Park'] = ['GHCND:USC00044555']
s_id_2014_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2014_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2014_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2014_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2014_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2014_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2014_prcp['Virgin Islands National Park'] = ['GHCND:VQC00672551']
s_id_2014_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2014_prcp['White Sands National Park'] = ['GHCND:US1NMOT0065']
s_id_2014_prcp['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2014_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2014_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2014_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2014_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2013_prcp={}
s_id_2013_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2013_prcp['Arches National Park'] = ['GHCND:US1UTGR0005']
s_id_2013_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2013_prcp['Big Bend National Park'] = ['GHCND:USC00418924']
s_id_2013_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2013_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2013_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2013_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2013_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2013_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2013_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2013_prcp['Congaree National Park'] = ['GHCND:US1SCCA0002']
s_id_2013_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2013_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2013_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2013_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2013_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2013_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2013_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2013_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2013_prcp['Glacier Bay National Park'] = ['GHCND:USW00025380']
s_id_2013_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2013_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2013_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2013_prcp['Great Basin National Park'] = ['GHCND:USW00053138']
s_id_2013_prcp['Great Sand Dunes National Park'] = ['GHCND:US1COSA0002']
s_id_2013_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2013_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2013_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2013_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2013_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2013_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2013_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2013_prcp['Joshua Tree National Park'] = ['GHCND:USC00049099']
s_id_2013_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2013_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2013_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2013_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2013_prcp['Lake Clark National Park'] = ['GHCND:USW00026562']
s_id_2013_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2013_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2013_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2013_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2013_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2013_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2013_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2013_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2013_prcp['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2013_prcp['Pinnacles National Park'] = ['GHCND:USC00044555']
s_id_2013_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2013_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2013_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2013_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2013_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2013_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2013_prcp['Virgin Islands National Park'] = ['GHCND:VQW00011624']
s_id_2013_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2013_prcp['White Sands National Park'] = ['GHCND:US1NMOT0065']
s_id_2013_prcp['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2013_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2013_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2013_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2013_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
s_id_2012_prcp={}
s_id_2012_prcp['Acadia National Park'] = ['GHCND:USC00172443']
s_id_2012_prcp['Arches National Park'] = ['GHCND:US1UTGR0005']
s_id_2012_prcp['Badlands National Park'] = ['GHCND:US1SDPN0019']
s_id_2012_prcp['Big Bend National Park'] = ['GHCND:USC00411715']
s_id_2012_prcp['Biscayne National Park'] = ['GHCND:USC00081306']
s_id_2012_prcp['Black Canyon of the Gunnison National Park'] = ['GHCND:USC00050754']
s_id_2012_prcp['Bryce Canyon National Park'] = ['GHCND:USS0012M26S']
s_id_2012_prcp['Canyonlands National Park'] = ['GHCND:USC00423600']
s_id_2012_prcp['Capitol Reef National Park'] = ['GHCND:USC00421171']
s_id_2012_prcp['Carlsbad Caverns National Park'] = ['GHCND:USC00290600']
s_id_2012_prcp['Channel Islands National Park'] = ['GHCND:USC00046572']
s_id_2012_prcp['Congaree National Park'] = ['GHCND:USW00053867']
s_id_2012_prcp['Crater Lake National Park'] = ['GHCND:USS0022G06S']
s_id_2012_prcp['Cuyahoga Valley National Park'] = ['GHCND:USW00014820']
s_id_2012_prcp['Death Valley National Park'] = ['GHCND:USC00042319']
s_id_2012_prcp['Denali National Park'] = ['GHCND:USS0050O01S']
s_id_2012_prcp['Dry Tortugas National Park'] = ['GHCND:USC00084571']
s_id_2012_prcp['Everglades National Park'] = ['GHCND:USW00092826']
s_id_2012_prcp['Gates of the Arctic National Park'] = ['GHCND:USS0050S01S']
s_id_2012_prcp['Gateway Arch National Park'] = ['GHCND:USW00003960']
s_id_2012_prcp['Glacier Bay National Park'] = ['GHCND:USC00507141']
s_id_2012_prcp['Glacier National Park'] = ['GHCND:USS0013A19S']
s_id_2012_prcp['Grand Canyon National Park'] = ['GHCND:USC00026471']
s_id_2012_prcp['Grand Teton National Park'] = ['GHCND:USS0010F30S']
s_id_2012_prcp['Great Basin National Park'] = ['GHCND:USW00053138']
s_id_2012_prcp['Great Sand Dunes National Park'] = ['GHCND:USC00053541']
s_id_2012_prcp['Great Smoky Mountains National Park'] = ['GHCND:USC00403420']
s_id_2012_prcp['Guadalupe Mountains National Park'] = ['GHCND:USC00290600']
s_id_2012_prcp['Haleakala National Park'] = ['GHCND:USC00515000']
s_id_2012_prcp['Hawaii Volcanoes National Park'] = ['GHCND:USW00021514']
s_id_2012_prcp['Hot Springs National Park'] = ['GHCND:USW00003962']
s_id_2012_prcp['Indiana Dunes National Park'] = ['GHCND:USC00111577']
s_id_2012_prcp['Isle Royale National Park'] = ['GHCND:USW00094992']
s_id_2012_prcp['Joshua Tree National Park'] = ['GHCND:USC00043855']
s_id_2012_prcp['Katmai National Park'] = ['GHCND:USS0051K05S']
s_id_2012_prcp['Kenai Fjords National Park'] = ['GHCND:USS0051K05S']
s_id_2012_prcp['Kings Canyon National Park'] = ['GHCND:USS0019L13S']
s_id_2012_prcp['Kobuk Valley National Park'] = ['GHCND:USW00026411']
s_id_2012_prcp['Lake Clark National Park'] = ['GHCND:USW00026562']
s_id_2012_prcp['Lassen Volcanic National Park'] = ['GHCND:USC00041700']
s_id_2012_prcp['Mammoth Cave National Park'] = ['GHCND:USC00155097']
s_id_2012_prcp['Mesa Verde National Park'] = ['GHCND:USC00055531']
s_id_2012_prcp['Mount Rainier National Park'] = ['GHCND:USS0021C40S']
s_id_2012_prcp['National Park of American Samoa'] = ['GHCND:AQW00061705']
s_id_2012_prcp['New River Gorge National Park'] = ['GHCND:USW00003872']
s_id_2012_prcp['North Cascades National Park'] = ['GHCND:USC00455840']
s_id_2012_prcp['Olympic National Park'] = ['GHCND:US1WATH0028']
s_id_2012_prcp['Petrified Forest National Park'] = ['GHCND:USC00026190']
s_id_2012_prcp['Pinnacles National Park'] = ['GHCND:US1CAMT0008']
s_id_2012_prcp['Redwood National Park'] = ['GHCND:USW00024283']
s_id_2012_prcp['Rocky Mountain National Park'] = ['GHCND:USS0005J39S']
s_id_2012_prcp['Saguaro National Park'] = ['GHCND:USW00053131']
s_id_2012_prcp['Sequoia National Park'] = ['GHCND:USS0019L13S']
s_id_2012_prcp['Shenandoah National Park'] = ['GHCND:US1VAPG0001']
s_id_2012_prcp['Theodore Roosevelt National Park'] = ['GHCND:USW00094080']
s_id_2012_prcp['Virgin Islands National Park'] = ['GHCND:VQW00011624']
s_id_2012_prcp['Voyageurs National Park'] = ['GHCND:USW00014918']
s_id_2012_prcp['White Sands National Park'] = ['GHCND:USC00299686']
s_id_2012_prcp['Wind Cave National Park'] = ['GHCND:USC00399347']
s_id_2012_prcp['Wrangell-St. Elias National Park'] = ['GHCND:USS0042M01S']
s_id_2012_prcp['Yellowstone National Park'] = ['GHCND:USS0011E07S']
s_id_2012_prcp['Yosemite National Park'] = ['GHCND:USS0019L13S']
s_id_2012_prcp['Zion National Park'] = ['GHCND:USS0012M06S']

# %%
temp_list=[s_id_2012,s_id_2013,s_id_2014,s_id_2015,s_id_2016,s_id_2017,s_id_2018,s_id_2019,s_id_2020,s_id_2021]
prcp_list=[s_id_2012_prcp,s_id_2013_prcp,s_id_2014_prcp,s_id_2015_prcp,s_id_2016_prcp,s_id_2017_prcp,s_id_2018_prcp,s_id_2019_prcp,s_id_2020_prcp,s_id_2021_prcp]
year_list=['2012','2013','2014','2015','2016','2017','2018','2019','2020','2021']
park_list=list(s_id_2012.keys())

# %%
Token = 'XpapSABquGPOSCjTdKfwjVJrPUAOYlFx'
datatype = 'TAVG'
temp_df=pd.DataFrame(index=range(1,13))
temp_df.index.rename('Month', inplace=True)
for park in park_list:
    lst=[0]*12
    for index, year_dict in enumerate(temp_list):
        year=year_list[index]
        station_id=year_dict[park][0]
        r = requests.get('https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&datatypeid='+datatype+'&limit=1000&units=standard&stationid='+station_id+'&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
        d=json.loads(r.text)
        time.sleep(0.5)
        for i, month in enumerate(d['results']):
            lst[i] += month['value']
    lst=[i/10 for i in lst]
    temp_df[park]=lst

# %%
temp_df
# Out:
#        Acadia National Park  Arches National Park  Badlands National Park  \
# Month
# 1                     22.30                 27.37                   27.33
# 2                     23.30                 37.07                   25.64
# 3                     30.82                 47.66                   39.94
# 4                     41.60                 54.62                   46.26
# 5                     52.18                 64.29                   56.41
# 6                     60.85                 76.91                   69.79
# 7                     67.55                 82.34                   75.58
# 8                     67.16                 78.89                   72.76
# 9                     59.71                 70.37                   65.28
# 10                    49.25                 55.03                   49.43
# 11                    36.71                 41.88                   38.77
# 12                    27.48                 29.00                   26.53
# ...

# %%
temp_df.to_csv('../assets/temperatures.csv')

# %%
Token = 'XpapSABquGPOSCjTdKfwjVJrPUAOYlFx'
datatype = 'PRCP'
prcp_df=pd.DataFrame(index=range(1,13))
prcp_df.index.rename('Month', inplace=True)
for park in park_list:
    lst=[0]*12
    for index, year_dict in enumerate(prcp_list):
        year=year_list[index]
        station_id=year_dict[park][0]
        r = requests.get('https://www.ncei.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&datatypeid='+datatype+'&limit=1000&units=standard&stationid='+station_id+'&startdate='+year+'-01-01&enddate='+year+'-12-31', headers={'token':Token})
        d=json.loads(r.text)
        time.sleep(0.5)
        for i, month in enumerate(d['results']):
            lst[i] += month['value']
    lst=[i/10 for i in lst]
    prcp_df[park]=lst

# %%
prcp_df
# Out:
#        Acadia National Park  Arches National Park  Badlands National Park  \
# Month
# 1                     3.911                 0.367                   0.364
# 2                     3.908                 0.331                   0.495
# 3                     3.359                 0.422                   1.100
# 4                     4.482                 0.495                   2.345
# 5                     3.817                 0.624                   3.803
# 6                     4.831                 0.311                   3.565
# 7                     3.009                 0.772                   2.356
# 8                     3.205                 0.789                   2.050
# 9                     4.158                 0.746                   1.593
# 10                    5.052                 0.831                   1.934
# 11                    5.126                 0.369                   0.422
# 12                    5.656                 0.512                   0.619
# ...

# %%
prcp_df.to_csv('../assets/precipitation.csv')

# %%
NPS_df=pd.read_csv('../assets/NPS_with_trends.csv', index_col=0)

# %%
NPS_df
# Out:
#                    ParkName UnitCode       ParkType          Region State  \
# 0      Acadia National Park     ACAD  National Park      Northeast     ME
# 1      Acadia National Park     ACAD  National Park      Northeast     ME
# 2      Acadia National Park     ACAD  National Park      Northeast     ME
# 3      Acadia National Park     ACAD  National Park      Northeast     ME
# 4      Acadia National Park     ACAD  National Park      Northeast     ME
# ...                     ...      ...            ...             ...   ...
# 12834    Zion National Park     ZION  National Park  Intermountain     UT
# 12835    Zion National Park     ZION  National Park  Intermountain     UT
# 12836    Zion National Park     ZION  National Park  Intermountain     UT
# 12837    Zion National Park     ZION  National Park  Intermountain     UT
# 12838    Zion National Park     ZION  National Park  Intermountain     UT
#
#        Year  Month  RecreationVisits  NonRecreationVisits  RecreationHours  \
# ...

# %%
NPS_df['Temp_Avg_Fahrenheit']=NPS_df.apply(lambda x: temp_df.loc[x.Month,x.ParkName],axis=1)
NPS_df['Prcp_Avg_Inches']=NPS_df.apply(lambda x: prcp_df.loc[x.Month,x.ParkName],axis=1)

# %%
NPS_df
# Out:
#                    ParkName UnitCode       ParkType          Region State  \
# 0      Acadia National Park     ACAD  National Park      Northeast     ME
# 1      Acadia National Park     ACAD  National Park      Northeast     ME
# 2      Acadia National Park     ACAD  National Park      Northeast     ME
# 3      Acadia National Park     ACAD  National Park      Northeast     ME
# 4      Acadia National Park     ACAD  National Park      Northeast     ME
# ...                     ...      ...            ...             ...   ...
# 12834    Zion National Park     ZION  National Park  Intermountain     UT
# 12835    Zion National Park     ZION  National Park  Intermountain     UT
# 12836    Zion National Park     ZION  National Park  Intermountain     UT
# 12837    Zion National Park     ZION  National Park  Intermountain     UT
# 12838    Zion National Park     ZION  National Park  Intermountain     UT
#
#        Year  Month  RecreationVisits  NonRecreationVisits  RecreationHours  \
# ...

# %%
NPS_df.to_csv('../assets/NPS_weather_trends.csv', index=False)
